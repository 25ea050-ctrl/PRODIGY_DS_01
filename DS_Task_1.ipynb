# %% [markdown]
# Task 1

# %% [markdown]
# Bar Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv(
    "API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv",
    skiprows=4
)
country = data["Country Name"].head(10)
population = data["2020"].head(10)

plt.bar(country, population)

plt.title("Population Distribution")
plt.xlabel("Country")
plt.ylabel("Population")

plt.xticks(rotation=90)

plt.show()
